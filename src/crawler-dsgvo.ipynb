# %% [markdown]
# # Crawler für die DSGVO-Website
#
# Die DSGVO kann in aufbereiteter Form auf der Webseite https://dsgvo-gesetz.de/ eingesehen werden. Hierbei handelt es sich um eine von intersoft consulting erstellte Webseite, die die DSGVO in einem einfachen Format präsentiert.
#
# ## Grundaufbau der Seiten
#
# Das Grundgerüst aller Seiten folgt dem folgenden Schema:
#
# ```html
# ...
# <body ...>
#   <div id="page" ...>
#     <div id="content" ...>
#       <div id="primary" ...>
#         <main id="main" ...>
#           <article id="post-##" ...>
#             <header class="entry-header">
#               <h1 class="entry-title">
#                 <span class="dsgvo-number">[TITEL]</span>
#                 <span class="dsgvo-title">[UNTERTITEL]</span>
#               </h1>
#             </header>
#             <div class="entry-content">
#               [INHALT]
#             </div>
#           </article>
#         </main>
#       </div>
#     </div>
#   </div>
# </body>
# ...
# ```
#
# ## Aufbau der Übersichtsseite
#
# Die Übersichtsseite enthält einen kurzen erklärenden Text und danach Links zu den 11 Unterkapiteln sowie direkte Links zu den einzelnen Artikeln.
#
# Der Titel der Seite ist "Datenschutz-Grundverordnung" und der Subtitel "DSGVO".
#
# Die URL lautet: https://dsgvo-gesetz.de/
#
# Der folgende Code zeigt den Inhalt der Seite, also des Platzhalters `[INHALT]`:
#
# ```html
# ::before
# <p>...</p>
# <h2>Schnellzugriff</h2>
# <table ...>...</table>
# <h2>Wichtige Themen</h2>
# <ul class="beliebte inhalte">...</ul>
# <div class="clear">...</div>
# <h2>Inhaltsverzeichnis</h2>
# <div class="liste-inhaltsuebersicht dsgvo">
#   [VERZEICHNIS]
# </div>
# <div class="feedback hidden-print">...</div>
# ::after
# ```
#
# Das Verzeichnis selbst ist wie folgt aufgebaut (Beispiel):
#
# ```html
# <div class="kapitel nomargin">...</div>
# <div class="artikel">...</div>
# <div class="kapitel">...</div>
# <div class="abschnitt">...</div>
# <div class="artikel">...</div>
# <div class="artikel">...</div>
# <div class="abschnitt">...</div>
# <div class="artikel">...</div>
# <div class="artikel">...</div>
# ```
#
# Dabei ist zu beachten, dass einzelne Kapitel entweder nur aus Artikeln bestehen (also keine Abschnitte enthalten), oder aus Abschnitten und Artikeln.
#
# ```html
# <div class="kapitel">
#   <span class="nummer">Kapitel 2</span>
#   <span class="titel">Grundsätze</span>
# </div>
# ```
#
# ```html
# <div class="abschnitt">
#   <span class="nummer">Abschnitt 1</span>
#   <span class="titel">Transparenz und Modalitäten</span>
# </div>
# ```
#
# ```html
# <div class="artikel">
#   <a href="https://dsgvo-gesetz.de/art-2-dsgvo/">
#     <span class="nummer">Artikel 2</span>
#     <span class="titel">Sachlicher Anwendungsbereich</span>
#   </a>
# </div>
# ```
#
# Beim Crawlen der Seiten wird das Verzeichnis in der Übersichtsseite durchlaufen und die Links zu den einzelnen Artikeln ausgelesen. Dabei ist die Reihenfolge entscheidend, da durch diese klar wird, zu welchem Kapitel und ggf. Abschnitt ein Artikel gehört.
#
# ## Aufbau einer Artikelseite
#
# URL eines Artikels: https://dsgvo-gesetz.de/art-##-dsgvo/
#
# Der Abschnitt [INHALT] ist im einfachsten Fall wie folgt aufgaubaut, wie bspw. Artikel 10:
#
# ```html
# <p>[TEXT]</p>
# ```
#
# Meistens besteht ein Artikel aber aus mehreren Absätzen, welche als `(n)` nummeriert sind. Ein Beispiel dafür wäre Artikel 1. In diesem Fall wäre die Darstellung wie folgt:
#
# ```html
# <ol>
#   <li>[TEXT_ABSATZ_1]</li>
#   <li>[TEXT_ABSATZ_2]</li>
#   <li>[TEXT_ABSATZ_3]</li>
# </ol>
# ```
#
# Es ist ausßerdem möglich, dass ein Absatz in mehrere Unterabsätze unterteilt ist. Ein Beispiel wäre Artikel 2:
#
# ```html
# <ol>
#   <li>[TEXT_ABSATZ_1]</li>
#   <li>
#     <p>[TEXT_UNTERABSATZ_0</p>
#     <ol>
#       <li>[TEXT_UNTERABSATZ_1]</li>
#       <li>[TEXT_UNTERABSATZ_2]</li>
#       <li>[TEXT_UNTERABSATZ_3]</li>
#       <li>[TEXT_UNTERABSATZ_4]</li>
#     <ol>
#   </li>
#   <li>[TEXT_ABSATZ_3]</li>
#   <li>[TEXT_ABSATZ_4]</li>
# </ol>
# ```
#
# Jeder der [TEXT...]-Platzhalter kann aus mehreren Sätzen bestehen. Falls dem so ist, wird jedem Satz ein `<sup>#</sup>` vorangestellt. Sollte nur ein Satz vorhanden sein, wird dieser ohne `<sup>#</sup>` dargestellt und es ist von Satz 1 auszugehen.
#
# ## Zielformat
#
# Es soll eine JSONL-Datei erstellt werden, welche die Daten in einem strukturierten Format enthält:
# - Kapitel_Nr
# - Kapitel_Name
# - Abschnitt_Nr
# - Abschnitt_Name
# - Artikel_Nr
# - Artikel_Name
# - Absatz_Nr (0 falls nicht explizit durch (#) angegeben)
# - Unterabsatz_Nr (0 falls nicht explizit durch (a), (b), (c), ... angegeben, ansonsten a=1, b=2, c=3, ...)
# - Satz_Nr (1 falls nicht explizit durch <sup>#</sup> angegeben)
# - Text
#
# ## Ausgabe
#
# Vom /src-Ordner ausgesehen:
# ../data/input/dsgvo_crawled.jsonl

# %%
from dataclasses import dataclass
from typing import Dict

@dataclass
class DSGVOEntry:
    """Repräsentiert einen DSGVO-Eintrag mit hierarchischer Struktur"""
    kapitel_nr: int
    kapitel_name: str
    abschnitt_nr: int       # 0 falls nicht vorhanden
    abschnitt_name: str     # "" falls nicht vorhanden
    artikel_nr: int
    artikel_name: str
    absatz_nr: int          # 0 falls nicht explizit durch (#) angegeben
    unterabsatz_nr: int     # 0 falls nicht explizit durch (a), (b), (c), ... angegeben, ansonsten a=1, b=2, c=3, ...
    satz_nr: int            # 1 falls nicht explizit durch <sup>#</sup> angegeben
    text: str

    def to_dict(self) -> Dict:
        """Konvertiert den Eintrag zu einem Dictionary für JSONL-Export"""
        return {
            'Kapitel_Nr': self.kapitel_nr,
            'Kapitel_Name': self.kapitel_name,
            'Abschnitt_Nr': self.abschnitt_nr,
            'Abschnitt_Name': self.abschnitt_name,
            'Artikel_nr': self.artikel_nr,
            'Artikel_Name': self.artikel_name,
            'Absatz_nr': self.absatz_nr,
            'Unterabsatz_nr': self.unterabsatz_nr,
            'Satz_nr': self.satz_nr,
            'Text': self.text
        }

# %%
import requests
import json
import logging
import time
from datetime import datetime
from pathlib import Path
from bs4 import BeautifulSoup
from typing import List, Tuple, Optional
import re

# Logging Setup
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('../data/logs/crawler.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# %%
class DSGVOCrawler:
    """DSGVO Website Crawler für https://dsgvo-gesetz.de/"""

    def __init__(self, base_url: str = "https://dsgvo-gesetz.de"):
        self.base_url = base_url
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        })

        # Struktur-Tracking
        self.current_kapitel = {"nr": 0, "name": ""}
        self.current_abschnitt = {"nr": 0, "name": ""}

    def get_page(self, url: str, retry_count: int = 3) -> Optional[BeautifulSoup]:
        """Lädt eine Seite mit Retry-Mechanismus"""
        for attempt in range(retry_count):
            try:
                logger.info(f"Lade Seite: {url} (Versuch {attempt + 1})")
                response = self.session.get(url, timeout=10)
                response.raise_for_status()

                soup = BeautifulSoup(response.content, 'lxml')
                time.sleep(1)  # Rate limiting
                return soup

            except requests.RequestException as e:
                logger.warning(f"Fehler beim Laden von {url}: {e}")
                if attempt == retry_count - 1:
                    logger.error(f"Alle Versuche fehlgeschlagen für: {url}")
                    return None
                time.sleep(2 ** attempt)  # Exponential backoff

        return None

    def parse_overview_page(self) -> List[Tuple[str, str]]:
        """
        Parst die Übersichtsseite und extrahiert alle Artikel-URLs
        Returns: Liste von (artikel_url, artikel_context) Tupeln
        """
        soup = self.get_page(self.base_url)
        if not soup:
            logger.error("Konnte Übersichtsseite nicht laden")
            return []

        # Finde das Inhaltsverzeichnis
        inhaltsverzeichnis = soup.find('div', class_='liste-inhaltsuebersicht dsgvo')
        if not inhaltsverzeichnis:
            logger.error("Inhaltsverzeichnis nicht gefunden")
            return []

        artikel_links = []

        # Durchlaufe alle Elemente im Verzeichnis
        for element in inhaltsverzeichnis.find_all(['div']):
            class_name = element.get('class', [])

            if 'kapitel' in class_name:
                # Neues Kapitel
                nummer_span = element.find('span', class_='nummer')
                titel_span = element.find('span', class_='titel')

                if nummer_span and titel_span:
                    # Extrahiere Kapitelnummer
                    kapitel_text = nummer_span.get_text(strip=True)
                    kapitel_match = re.search(r'(\d+)', kapitel_text)
                    self.current_kapitel['nr'] = int(kapitel_match.group(1)) if kapitel_match else 0
                    self.current_kapitel['name'] = titel_span.get_text(strip=True)

                    # Reset Abschnitt
                    self.current_abschnitt = {"nr": 0, "name": ""}

                    logger.info(f"Gefunden: Kapitel {self.current_kapitel['nr']} - {self.current_kapitel['name']}")

            elif 'abschnitt' in class_name:
                # Neuer Abschnitt
                nummer_span = element.find('span', class_='nummer')
                titel_span = element.find('span', class_='titel')

                if nummer_span and titel_span:
                    # Extrahiere Abschnittsnummer
                    abschnitt_text = nummer_span.get_text(strip=True)
                    abschnitt_match = re.search(r'(\d+)', abschnitt_text)
                    self.current_abschnitt['nr'] = int(abschnitt_match.group(1)) if abschnitt_match else 0
                    self.current_abschnitt['name'] = titel_span.get_text(strip=True)

                    logger.info(f"Gefunden: Abschnitt {self.current_abschnitt['nr']} - {self.current_abschnitt['name']}")

            elif 'artikel' in class_name:
                # Artikel-Link
                link = element.find('a')
                if link and link.get('href'):
                    artikel_url = link.get('href')

                    # Kontext für diesen Artikel speichern
                    context = {
                        'kapitel_nr': self.current_kapitel['nr'],
                        'kapitel_name': self.current_kapitel['name'],
                        'abschnitt_nr': self.current_abschnitt['nr'],
                        'abschnitt_name': self.current_abschnitt['name']
                    }

                    artikel_links.append((artikel_url, context))

        logger.info(f"Insgesamt {len(artikel_links)} Artikel gefunden")
        return artikel_links

    def parse_article_page(self, url: str, context: dict) -> List[DSGVOEntry]:
        """
        Parst eine einzelne Artikelseite und extrahiert alle Einträge
        """
        soup = self.get_page(url)
        if not soup:
            logger.error(f"Konnte Artikel nicht laden: {url}")
            return []

        entries = []

        # Extrahiere Artikel-Info aus dem Header
        header = soup.find('header', class_='entry-header')
        if not header:
            logger.error(f"Header nicht gefunden in: {url}")
            return []

        # Artikel Nummer und Name
        dsgvo_number = header.find('span', class_='dsgvo-number')
        dsgvo_title = header.find('span', class_='dsgvo-title')

        if not dsgvo_number or not dsgvo_title:
            logger.error(f"Artikel-Info nicht gefunden in: {url}")
            return []

        artikel_text = dsgvo_number.get_text(strip=True)
        artikel_match = re.search(r'(\d+)', artikel_text)
        artikel_nr = int(artikel_match.group(1)) if artikel_match else 0
        artikel_name = dsgvo_title.get_text(strip=True)

        logger.info(f"Parse Artikel {artikel_nr}: {artikel_name}")

        # Extrahiere Inhalt
        content_div = soup.find('div', class_='entry-content')
        if not content_div:
            logger.error(f"Content nicht gefunden in: {url}")
            return []

        # Prüfe ob es sich um einen einfachen Artikel handelt (nur <p> Tags)
        paragraphs = content_div.find_all('p', recursive=False)
        if paragraphs and not content_div.find('ol', recursive=False):
            # Einfacher Artikel ohne nummerierte Absätze
            for p in paragraphs:
                text = p.get_text(strip=True)
                if text and not self._is_navigation_text(text):
                    # Prüfe auf Satz-Nummerierung mit <sup>
                    sentences = self._parse_sentences(p)
                    for satz_nr, satz_text in sentences:
                        entry = DSGVOEntry(
                            kapitel_nr=context['kapitel_nr'],
                            kapitel_name=context['kapitel_name'],
                            abschnitt_nr=context['abschnitt_nr'],
                            abschnitt_name=context['abschnitt_name'],
                            artikel_nr=artikel_nr,
                            artikel_name=artikel_name,
                            absatz_nr=0,  # Kein expliziter Absatz
                            unterabsatz_nr=0,  # Kein Unterabsatz
                            satz_nr=satz_nr,
                            text=satz_text
                        )
                        entries.append(entry)
        else:
            # Komplexer Artikel mit nummerierten Absätzen
            ol_elements = content_div.find_all('ol', recursive=False)
            for ol in ol_elements:
                entries.extend(self._parse_ordered_list(ol, context, artikel_nr, artikel_name))

        return entries

    def _parse_ordered_list(self, ol_element, context: dict, artikel_nr: int, artikel_name: str, parent_absatz: int = 0) -> List[DSGVOEntry]:
        """
        Parst eine <ol> Liste rekursiv für Absätze und Unterabsätze
        """
        entries = []

        for i, li in enumerate(ol_element.find_all('li', recursive=False), 1):
            absatz_nr = i if parent_absatz == 0 else parent_absatz

            # Prüfe ob es verschachtelte Listen gibt (Unterabsätze)
            nested_ol = li.find('ol')

            if nested_ol:
                # Dieser li hat Unterabsätze
                # Extrahiere Text vor der verschachtelten Liste
                li_copy = li.__copy__()
                nested_ol_copy = li_copy.find('ol')
                if nested_ol_copy:
                    nested_ol_copy.decompose()  # Entferne die verschachtelte Liste

                intro_text = li_copy.get_text(strip=True)
                if intro_text:
                    # Einleitungstext des Absatzes
                    sentences = self._parse_sentences_from_text(intro_text)
                    for satz_nr, satz_text in sentences:
                        entry = DSGVOEntry(
                            kapitel_nr=context['kapitel_nr'],
                            kapitel_name=context['kapitel_name'],
                            abschnitt_nr=context['abschnitt_nr'],
                            abschnitt_name=context['abschnitt_name'],
                            artikel_nr=artikel_nr,
                            artikel_name=artikel_name,
                            absatz_nr=absatz_nr,
                            unterabsatz_nr=0,  # Einleitungstext
                            satz_nr=satz_nr,
                            text=satz_text
                        )
                        entries.append(entry)

                # Parse Unterabsätze
                for j, sub_li in enumerate(nested_ol.find_all('li', recursive=False), 1):
                    text = sub_li.get_text(strip=True)
                    if text:
                        sentences = self._parse_sentences_from_text(text)
                        for satz_nr, satz_text in sentences:
                            entry = DSGVOEntry(
                                kapitel_nr=context['kapitel_nr'],
                                kapitel_name=context['kapitel_name'],
                                abschnitt_nr=context['abschnitt_nr'],
                                abschnitt_name=context['abschnitt_name'],
                                artikel_nr=artikel_nr,
                                artikel_name=artikel_name,
                                absatz_nr=absatz_nr,
                                unterabsatz_nr=j,  # a=1, b=2, c=3, ...
                                satz_nr=satz_nr,
                                text=satz_text
                            )
                            entries.append(entry)
            else:
                # Normaler Absatz ohne Unterabsätze
                text = li.get_text(strip=True)
                if text:
                    sentences = self._parse_sentences_from_text(text)
                    for satz_nr, satz_text in sentences:
                        entry = DSGVOEntry(
                            kapitel_nr=context['kapitel_nr'],
                            kapitel_name=context['kapitel_name'],
                            abschnitt_nr=context['abschnitt_nr'],
                            abschnitt_name=context['abschnitt_name'],
                            artikel_nr=artikel_nr,
                            artikel_name=artikel_name,
                            absatz_nr=absatz_nr,
                            unterabsatz_nr=0,
                            satz_nr=satz_nr,
                            text=satz_text
                        )
                        entries.append(entry)

        return entries

    def _parse_sentences(self, element) -> List[Tuple[int, str]]:
        """
        Parst Sätze aus einem HTML-Element und erkennt <sup> Nummerierung
        """
        sentences = []

        # Prüfe auf <sup> Tags für Satz-Nummerierung
        sup_tags = element.find_all('sup')

        if sup_tags:
            # Es gibt nummerierte Sätze
            for sup in sup_tags:
                satz_nr_text = sup.get_text(strip=True)
                try:
                    satz_nr = int(satz_nr_text)
                except ValueError:
                    satz_nr = 1

                # Extrahiere Text nach dem <sup> Tag bis zum nächsten <sup> oder Ende
                text_parts = []
                current = sup.next_sibling

                while current and (not hasattr(current, 'name') or current.name != 'sup'):
                    if hasattr(current, 'get_text'):
                        text_parts.append(current.get_text())
                    else:
                        text_parts.append(str(current))
                    current = current.next_sibling

                satz_text = ''.join(text_parts).strip()
                if satz_text:
                    sentences.append((satz_nr, satz_text))
        else:
            # Kein <sup> Tag gefunden, gesamter Text ist Satz 1
            text = element.get_text(strip=True)
            if text:
                sentences.append((1, text))

        return sentences

    def _parse_sentences_from_text(self, text: str) -> List[Tuple[int, str]]:
        """
        Parst Sätze aus einem Text-String (fallback für bereits extrahierten Text)
        """
        # Einfache Implementation: Text ist ein Satz
        if text.strip():
            return [(1, text.strip())]
        return []

    def _is_navigation_text(self, text: str) -> bool:
        """
        Prüft ob es sich um Navigations- oder Meta-Text handelt
        """
        navigation_keywords = [
            'feedback', 'bewertung', 'drucken', 'teilen',
            'weitere artikel', 'siehe auch', 'navigation'
        ]
        text_lower = text.lower()
        return any(keyword in text_lower for keyword in navigation_keywords)

    def crawl_all_articles(self) -> List[DSGVOEntry]:
        """
        Hauptmethode: Crawlt alle Artikel und gibt strukturierte Daten zurück
        """
        logger.info("Starte DSGVO Crawler...")

        # 1. Parse Übersichtsseite für Artikel-Links
        artikel_links = self.parse_overview_page()
        if not artikel_links:
            logger.error("Keine Artikel gefunden")
            return []

        all_entries = []

        # 2. Parse jeden Artikel
        for i, (artikel_url, context) in enumerate(artikel_links, 1):
            logger.info(f"Verarbeite Artikel {i}/{len(artikel_links)}: {artikel_url}")

            try:
                entries = self.parse_article_page(artikel_url, context)
                all_entries.extend(entries)
                logger.info(f"Artikel {i}: {len(entries)} Einträge extrahiert")

            except Exception as e:
                logger.error(f"Fehler beim Verarbeiten von {artikel_url}: {e}")
                continue

        logger.info(f"Crawling abgeschlossen. Insgesamt {len(all_entries)} Einträge extrahiert.")
        return all_entries

    def save_to_jsonl(self, entries: List[DSGVOEntry], output_path: str):
        """
        Speichert die Einträge als JSONL-Datei
        """
        # Erstelle Output-Verzeichnis falls nicht vorhanden
        output_file = Path(output_path)
        output_file.parent.mkdir(parents=True, exist_ok=True)

        logger.info(f"Speichere {len(entries)} Einträge in: {output_path}")

        with open(output_path, 'w', encoding='utf-8') as f:
            for entry in entries:
                json_line = json.dumps(entry.to_dict(), ensure_ascii=False)
                f.write(json_line + '\n')

        logger.info(f"Erfolgreich gespeichert: {output_path}")

    def run_full_crawl(self, output_path: str = None):
        """
        Führt einen vollständigen Crawl-Durchlauf aus
        """
        if output_path is None:
            timestamp = datetime.now().strftime("%Y-%m-%d_%H%M")
            output_path = f"../data/output/dsgvo_crawled_{timestamp}.jsonl"

        try:
            # Crawle alle Artikel
            entries = self.crawl_all_articles()

            if entries:
                # Speichere Ergebnisse
                self.save_to_jsonl(entries, output_path)

                # Statistiken
                logger.info("=== CRAWLING STATISTIKEN ===")
                logger.info(f"Gesamt Einträge: {len(entries)}")

                # Gruppiere nach Artikeln
                artikel_count = len(set((e.artikel_nr for e in entries)))
                logger.info(f"Artikel verarbeitet: {artikel_count}")

                # Gruppiere nach Kapiteln
                kapitel_count = len(set((e.kapitel_nr for e in entries)))
                logger.info(f"Kapitel verarbeitet: {kapitel_count}")

                return output_path
            else:
                logger.error("Keine Einträge zum Speichern gefunden")
                return None

        except Exception as e:
            logger.error(f"Fehler beim Crawling: {e}")
            return None

# %%
# Beispiel-Verwendung und Test des Crawlers

if __name__ == "__main__":
    # Erstelle Crawler-Instanz
    crawler = DSGVOCrawler()

    # Führe vollständigen Crawl aus
    output_file = crawler.run_full_crawl()

    if output_file:
        print(f"\\n✅ Crawling erfolgreich abgeschlossen!")
        print(f"📄 Ausgabedatei: {output_file}")
        print(f"📁 Log-Datei: ../data/logs/crawler.log")

        # Kurze Vorschau der ersten Einträge
        with open(output_file, 'r', encoding='utf-8') as f:
            lines = f.readlines()[:3]
            print(f"\\n📋 Erste {len(lines)} Einträge:")
            for i, line in enumerate(lines, 1):
                entry = json.loads(line)
                print(f"{i}. Artikel {entry['Artikel_nr']}, Absatz {entry['Absatz_nr']}, Satz {entry['Satz_nr']}")
                print(f"   Text: {entry['Text'][:100]}...")
    else:
        print("❌ Crawling fehlgeschlagen!")
# Out:
# 2025-08-11 12:04:44,762 - INFO - Starte DSGVO Crawler...
# 2025-08-11 12:04:44,763 - INFO - Lade Seite: https://dsgvo-gesetz.de (Versuch 1)
# 2025-08-11 12:04:45,989 - INFO - Gefunden: Kapitel 1 - Allgemeine Bestimmungen
# 2025-08-11 12:04:45,991 - INFO - Gefunden: Kapitel 2 - Grundsätze
# 2025-08-11 12:04:45,994 - INFO - Gefunden: Kapitel 3 - Rechte der betroffenen Person
# 2025-08-11 12:04:45,997 - INFO - Gefunden: Abschnitt 1 - Transparenz und Modalitäten
# 2025-08-11 12:04:45,999 - INFO - Gefunden: Abschnitt 2 - Informationspflicht und Recht auf Auskunft zu personenbezogenen Daten
# 2025-08-11 12:04:46,002 - INFO - Gefunden: Abschnitt 3 - Berichtigung und Löschung
# 2025-08-11 12:04:46,004 - INFO - Gefunden: Abschnitt 4 - Widerspruchsrecht und automatisierte Entscheidungsfindung im Einzelfall
# 2025-08-11 12:04:46,007 - INFO - Gefunden: Abschnitt 5 - Beschränkungen
# 2025-08-11 12:04:46,009 - INFO - Gefunden: Kapitel 4 - Verantwortlicher und Auftragsverarbeiter
# 2025-08-11 12:04:46,010 - INFO - Gefunden: Abschnitt 1 - Allgemeine Pflichten
# 2025-08-11 12:04:46,012 - INFO - Gefunden: Abschnitt 2 - Sicherheit personenbezogener Daten
# 2025-08-11 12:04:46,013 - INFO - Gefunden: Abschnitt 3 - Datenschutz-Folgenabschätzung und vorherige Konsultation
# 2025-08-11 12:04:46,014 - INFO - Gefunden: Abschnitt 4 - Datenschutzbeauftragter
# 2025-08-11 12:04:46,015 - INFO - Gefunden: Abschnitt 5 - Verhaltensregeln und Zertifizierung
# 2025-08-11 12:04:46,016 - INFO - Gefunden: Kapitel 5 - Übermittlungen personenbezogener Daten an Drittländer oder an internationale Organisationen
# 2025-08-11 12:04:46,017 - INFO - Gefunden: Kapitel 6 - Unabhängige Aufsichtsbehörden
# 2025-08-11 12:04:46,018 - INFO - Gefunden: Abschnitt 1 - Unabhängigkeit
# 2025-08-11 12:04:46,020 - INFO - Gefunden: Abschnitt 2 - Zuständigkeit, Aufgaben und Befugnisse
# 2025-08-11 12:04:46,021 - INFO - Gefunden: Kapitel 7 - Zusammenarbeit und Kohärenz
# 2025-08-11 12:04:46,023 - INFO - Gefunden: Abschnitt 1 - Zusammenarbeit
# 2025-08-11 12:04:46,024 - INFO - Gefunden: Abschnitt 2 - Kohärenz
# 2025-08-11 12:04:46,024 - INFO - Gefunden: Abschnitt 3 - Europäischer Datenschutzausschuss
# 2025-08-11 12:04:46,025 - INFO - Gefunden: Kapitel 8 - Rechtsbehelfe, Haftung und Sanktionen
# 2025-08-11 12:04:46,026 - INFO - Gefunden: Kapitel 9 - Vorschriften für besondere Verarbeitungssituationen
# 2025-08-11 12:04:46,027 - INFO - Gefunden: Kapitel 10 - Delegierte Rechtsakte und Durchführungsrechtsakte
# 2025-08-11 12:04:46,028 - INFO - Gefunden: Kapitel 11 - Schlussbestimmungen
# 2025-08-11 12:04:46,028 - INFO - Insgesamt 99 Artikel gefunden
# 2025-08-11 12:04:46,029 - INFO - Verarbeite Artikel 1/99: https://dsgvo-gesetz.de/art-1-dsgvo/
# 2025-08-11 12:04:46,029 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-1-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:47,082 - INFO - Parse Artikel 1: Gegenstand und Ziele
# 2025-08-11 12:04:47,083 - INFO - Artikel 1: 3 Einträge extrahiert
# 2025-08-11 12:04:47,084 - INFO - Verarbeite Artikel 2/99: https://dsgvo-gesetz.de/art-2-dsgvo/
# 2025-08-11 12:04:47,085 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-2-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:48,146 - INFO - Parse Artikel 2: Sachlicher Anwendungsbereich
# 2025-08-11 12:04:48,148 - INFO - Artikel 2: 8 Einträge extrahiert
# 2025-08-11 12:04:48,148 - INFO - Verarbeite Artikel 3/99: https://dsgvo-gesetz.de/art-3-dsgvo/
# 2025-08-11 12:04:48,149 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-3-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:49,210 - INFO - Parse Artikel 3: Räumlicher Anwendungsbereich
# 2025-08-11 12:04:49,212 - INFO - Artikel 3: 5 Einträge extrahiert
# 2025-08-11 12:04:49,212 - INFO - Verarbeite Artikel 4/99: https://dsgvo-gesetz.de/art-4-dsgvo/
# 2025-08-11 12:04:49,213 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-4-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:50,277 - INFO - Parse Artikel 4: Begriffsbestimmungen
# 2025-08-11 12:04:50,279 - INFO - Artikel 4: 33 Einträge extrahiert
# 2025-08-11 12:04:50,279 - INFO - Verarbeite Artikel 5/99: https://dsgvo-gesetz.de/art-5-dsgvo/
# 2025-08-11 12:04:50,280 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-5-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:51,335 - INFO - Parse Artikel 5: Grundsätze für die Verarbeitung personenbezogener Daten
# 2025-08-11 12:04:51,338 - INFO - Artikel 5: 8 Einträge extrahiert
# 2025-08-11 12:04:51,340 - INFO - Verarbeite Artikel 6/99: https://dsgvo-gesetz.de/art-6-dsgvo/
# 2025-08-11 12:04:51,340 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-6-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:52,423 - INFO - Parse Artikel 6: Rechtmäßigkeit der Verarbeitung
# 2025-08-11 12:04:52,426 - INFO - Artikel 6: 17 Einträge extrahiert
# 2025-08-11 12:04:52,426 - INFO - Verarbeite Artikel 7/99: https://dsgvo-gesetz.de/art-7-dsgvo/
# 2025-08-11 12:04:52,427 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-7-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:53,476 - INFO - Parse Artikel 7: Bedingungen für die Einwilligung
# 2025-08-11 12:04:53,478 - INFO - Artikel 7: 4 Einträge extrahiert
# 2025-08-11 12:04:53,478 - INFO - Verarbeite Artikel 8/99: https://dsgvo-gesetz.de/art-8-dsgvo/
# 2025-08-11 12:04:53,478 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-8-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:54,534 - INFO - Parse Artikel 8: Bedingungen für die Einwilligung eines Kindes in Bezug auf Dienste der Informationsgesellschaft
# 2025-08-11 12:04:54,536 - INFO - Artikel 8: 3 Einträge extrahiert
# 2025-08-11 12:04:54,537 - INFO - Verarbeite Artikel 9/99: https://dsgvo-gesetz.de/art-9-dsgvo/
# 2025-08-11 12:04:54,537 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-9-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:55,588 - INFO - Parse Artikel 9: Verarbeitung besonderer Kategorien personenbezogener Daten
# 2025-08-11 12:04:55,590 - INFO - Artikel 9: 14 Einträge extrahiert
# 2025-08-11 12:04:55,590 - INFO - Verarbeite Artikel 10/99: https://dsgvo-gesetz.de/art-10-dsgvo/
# 2025-08-11 12:04:55,590 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-10-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:56,641 - INFO - Parse Artikel 10: Verarbeitung von personenbezogenen Daten über strafrechtliche Verurteilungen und Straftaten
# 2025-08-11 12:04:56,646 - INFO - Artikel 10: 2 Einträge extrahiert
# 2025-08-11 12:04:56,646 - INFO - Verarbeite Artikel 11/99: https://dsgvo-gesetz.de/art-11-dsgvo/
# 2025-08-11 12:04:56,646 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-11-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:57,693 - INFO - Parse Artikel 11: Verarbeitung, für die eine Identifizierung der betroffenen Person nicht erforderlich ist
# 2025-08-11 12:04:57,695 - INFO - Artikel 11: 2 Einträge extrahiert
# 2025-08-11 12:04:57,696 - INFO - Verarbeite Artikel 12/99: https://dsgvo-gesetz.de/art-12-dsgvo/
# 2025-08-11 12:04:57,697 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-12-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:58,760 - INFO - Parse Artikel 12: Transparente Information, Kommunikation und Modalitäten für die Ausübung der Rechte der betroffenen Person
# 2025-08-11 12:04:58,763 - INFO - Artikel 12: 8 Einträge extrahiert
# 2025-08-11 12:04:58,763 - INFO - Verarbeite Artikel 13/99: https://dsgvo-gesetz.de/art-13-dsgvo/
# 2025-08-11 12:04:58,764 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-13-dsgvo/ (Versuch 1)
# 2025-08-11 12:04:59,827 - INFO - Parse Artikel 13: Informationspflicht bei Erhebung von personenbezogenen Daten bei der betroffenen Person
# 2025-08-11 12:04:59,830 - INFO - Artikel 13: 16 Einträge extrahiert
# 2025-08-11 12:04:59,830 - INFO - Verarbeite Artikel 14/99: https://dsgvo-gesetz.de/art-14-dsgvo/
# 2025-08-11 12:04:59,831 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-14-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:00,887 - INFO - Parse Artikel 14: Informationspflicht, wenn die personenbezogenen Daten nicht bei der betroffenen Person erhoben wurden
# 2025-08-11 12:05:00,890 - INFO - Artikel 14: 25 Einträge extrahiert
# 2025-08-11 12:05:00,891 - INFO - Verarbeite Artikel 15/99: https://dsgvo-gesetz.de/art-15-dsgvo/
# 2025-08-11 12:05:00,892 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-15-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:01,956 - INFO - Parse Artikel 15: Auskunftsrecht der betroffenen Person
# 2025-08-11 12:05:01,958 - INFO - Artikel 15: 12 Einträge extrahiert
# 2025-08-11 12:05:01,959 - INFO - Verarbeite Artikel 16/99: https://dsgvo-gesetz.de/art-16-dsgvo/
# 2025-08-11 12:05:01,960 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-16-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:03,015 - INFO - Parse Artikel 16: Recht auf Berichtigung
# 2025-08-11 12:05:03,018 - INFO - Artikel 16: 2 Einträge extrahiert
# 2025-08-11 12:05:03,019 - INFO - Verarbeite Artikel 17/99: https://dsgvo-gesetz.de/art-17-dsgvo/
# 2025-08-11 12:05:03,019 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-17-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:04,084 - INFO - Parse Artikel 17: Recht auf Löschung ("Recht auf Vergessenwerden")
# 2025-08-11 12:05:04,088 - INFO - Artikel 17: 14 Einträge extrahiert
# 2025-08-11 12:05:04,089 - INFO - Verarbeite Artikel 18/99: https://dsgvo-gesetz.de/art-18-dsgvo/
# 2025-08-11 12:05:04,090 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-18-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:05,148 - INFO - Parse Artikel 18: Recht auf Einschränkung der Verarbeitung
# 2025-08-11 12:05:05,150 - INFO - Artikel 18: 7 Einträge extrahiert
# 2025-08-11 12:05:05,150 - INFO - Verarbeite Artikel 19/99: https://dsgvo-gesetz.de/art-19-dsgvo/
# 2025-08-11 12:05:05,151 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-19-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:06,211 - INFO - Parse Artikel 19: Mitteilungspflicht im Zusammenhang mit der Berichtigung oder Löschung personenbezogener Daten oder der Einschränkung der Verarbeitung
# 2025-08-11 12:05:06,212 - INFO - Artikel 19: 2 Einträge extrahiert
# 2025-08-11 12:05:06,212 - INFO - Verarbeite Artikel 20/99: https://dsgvo-gesetz.de/art-20-dsgvo/
# 2025-08-11 12:05:06,213 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-20-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:07,272 - INFO - Parse Artikel 20: Recht auf Datenübertragbarkeit
# 2025-08-11 12:05:07,273 - INFO - Artikel 20: 6 Einträge extrahiert
# 2025-08-11 12:05:07,274 - INFO - Verarbeite Artikel 21/99: https://dsgvo-gesetz.de/art-21-dsgvo/
# 2025-08-11 12:05:07,275 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-21-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:08,334 - INFO - Parse Artikel 21: Widerspruchsrecht
# 2025-08-11 12:05:08,335 - INFO - Artikel 21: 6 Einträge extrahiert
# 2025-08-11 12:05:08,336 - INFO - Verarbeite Artikel 22/99: https://dsgvo-gesetz.de/art-22-dsgvo/
# 2025-08-11 12:05:08,336 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-22-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:09,426 - INFO - Parse Artikel 22: Automatisierte Entscheidungen im Einzelfall einschließlich Profiling
# 2025-08-11 12:05:09,428 - INFO - Artikel 22: 7 Einträge extrahiert
# 2025-08-11 12:05:09,429 - INFO - Verarbeite Artikel 23/99: https://dsgvo-gesetz.de/art-23-dsgvo/
# 2025-08-11 12:05:09,429 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-23-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:10,477 - INFO - Parse Artikel 23: Beschränkungen
# 2025-08-11 12:05:10,481 - INFO - Artikel 23: 20 Einträge extrahiert
# 2025-08-11 12:05:10,481 - INFO - Verarbeite Artikel 24/99: https://dsgvo-gesetz.de/art-24-dsgvo/
# 2025-08-11 12:05:10,482 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-24-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:11,531 - INFO - Parse Artikel 24: Verantwortung des für die Verarbeitung Verantwortlichen
# 2025-08-11 12:05:11,534 - INFO - Artikel 24: 3 Einträge extrahiert
# 2025-08-11 12:05:11,535 - INFO - Verarbeite Artikel 25/99: https://dsgvo-gesetz.de/art-25-dsgvo/
# 2025-08-11 12:05:11,536 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-25-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:12,584 - INFO - Parse Artikel 25: Datenschutz durch Technikgestaltung und durch datenschutzfreundliche Voreinstellungen
# 2025-08-11 12:05:12,586 - INFO - Artikel 25: 3 Einträge extrahiert
# 2025-08-11 12:05:12,587 - INFO - Verarbeite Artikel 26/99: https://dsgvo-gesetz.de/art-26-dsgvo/
# 2025-08-11 12:05:12,587 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-26-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:13,641 - INFO - Parse Artikel 26: Gemeinsam Verantwortliche
# 2025-08-11 12:05:13,642 - INFO - Artikel 26: 3 Einträge extrahiert
# 2025-08-11 12:05:13,643 - INFO - Verarbeite Artikel 27/99: https://dsgvo-gesetz.de/art-27-dsgvo/
# 2025-08-11 12:05:13,643 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-27-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:14,694 - INFO - Parse Artikel 27: Vertreter von nicht in der Union niedergelassenen Verantwortlichen oder Auftragsverarbeitern
# 2025-08-11 12:05:14,696 - INFO - Artikel 27: 7 Einträge extrahiert
# 2025-08-11 12:05:14,696 - INFO - Verarbeite Artikel 28/99: https://dsgvo-gesetz.de/art-28-dsgvo/
# 2025-08-11 12:05:14,697 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-28-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:15,768 - INFO - Parse Artikel 28: Auftragsverarbeiter
# 2025-08-11 12:05:15,771 - INFO - Artikel 28: 18 Einträge extrahiert
# 2025-08-11 12:05:15,771 - INFO - Verarbeite Artikel 29/99: https://dsgvo-gesetz.de/art-29-dsgvo/
# 2025-08-11 12:05:15,772 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-29-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:17,035 - INFO - Parse Artikel 29: Verarbeitung unter der Aufsicht des Verantwortlichen oder des Auftragsverarbeiters
# 2025-08-11 12:05:17,039 - INFO - Artikel 29: 1 Einträge extrahiert
# 2025-08-11 12:05:17,040 - INFO - Verarbeite Artikel 30/99: https://dsgvo-gesetz.de/art-30-dsgvo/
# 2025-08-11 12:05:17,042 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-30-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:18,118 - INFO - Parse Artikel 30: Verzeichnis von Verarbeitungstätigkeiten
# 2025-08-11 12:05:18,121 - INFO - Artikel 30: 16 Einträge extrahiert
# 2025-08-11 12:05:18,122 - INFO - Verarbeite Artikel 31/99: https://dsgvo-gesetz.de/art-31-dsgvo/
# 2025-08-11 12:05:18,122 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-31-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:19,192 - INFO - Parse Artikel 31: Zusammenarbeit mit der Aufsichtsbehörde
# 2025-08-11 12:05:19,194 - INFO - Artikel 31: 1 Einträge extrahiert
# 2025-08-11 12:05:19,194 - INFO - Verarbeite Artikel 32/99: https://dsgvo-gesetz.de/art-32-dsgvo/
# 2025-08-11 12:05:19,194 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-32-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:20,456 - INFO - Parse Artikel 32: Sicherheit der Verarbeitung
# 2025-08-11 12:05:20,460 - INFO - Artikel 32: 8 Einträge extrahiert
# 2025-08-11 12:05:20,461 - INFO - Verarbeite Artikel 33/99: https://dsgvo-gesetz.de/art-33-dsgvo/
# 2025-08-11 12:05:20,463 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-33-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:21,738 - INFO - Parse Artikel 33: Meldung von Verletzungen des Schutzes personenbezogener Daten an die Aufsichtsbehörde
# 2025-08-11 12:05:21,741 - INFO - Artikel 33: 9 Einträge extrahiert
# 2025-08-11 12:05:21,743 - INFO - Verarbeite Artikel 34/99: https://dsgvo-gesetz.de/art-34-dsgvo/
# 2025-08-11 12:05:21,744 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-34-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:22,813 - INFO - Parse Artikel 34: Benachrichtigung der von einer Verletzung des Schutzes personenbezogener Daten betroffenen Person
# 2025-08-11 12:05:22,815 - INFO - Artikel 34: 7 Einträge extrahiert
# 2025-08-11 12:05:22,816 - INFO - Verarbeite Artikel 35/99: https://dsgvo-gesetz.de/art-35-dsgvo/
# 2025-08-11 12:05:22,816 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-35-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:23,862 - INFO - Parse Artikel 35: Datenschutz-Folgenabschätzung
# 2025-08-11 12:05:23,865 - INFO - Artikel 35: 18 Einträge extrahiert
# 2025-08-11 12:05:23,866 - INFO - Verarbeite Artikel 36/99: https://dsgvo-gesetz.de/art-36-dsgvo/
# 2025-08-11 12:05:23,866 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-36-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:25,140 - INFO - Parse Artikel 36: Vorherige Konsultation
# 2025-08-11 12:05:25,144 - INFO - Artikel 36: 11 Einträge extrahiert
# 2025-08-11 12:05:25,146 - INFO - Verarbeite Artikel 37/99: https://dsgvo-gesetz.de/art-37-dsgvo/
# 2025-08-11 12:05:25,148 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-37-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:26,211 - INFO - Parse Artikel 37: Benennung eines Datenschutzbeauftragten
# 2025-08-11 12:05:26,213 - INFO - Artikel 37: 10 Einträge extrahiert
# 2025-08-11 12:05:26,213 - INFO - Verarbeite Artikel 38/99: https://dsgvo-gesetz.de/art-38-dsgvo/
# 2025-08-11 12:05:26,214 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-38-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:27,276 - INFO - Parse Artikel 38: Stellung des Datenschutzbeauftragten
# 2025-08-11 12:05:27,277 - INFO - Artikel 38: 6 Einträge extrahiert
# 2025-08-11 12:05:27,279 - INFO - Verarbeite Artikel 39/99: https://dsgvo-gesetz.de/art-39-dsgvo/
# 2025-08-11 12:05:27,279 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-39-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:28,340 - INFO - Parse Artikel 39: Aufgaben des Datenschutzbeauftragten
# 2025-08-11 12:05:28,342 - INFO - Artikel 39: 7 Einträge extrahiert
# 2025-08-11 12:05:28,343 - INFO - Verarbeite Artikel 40/99: https://dsgvo-gesetz.de/art-40-dsgvo/
# 2025-08-11 12:05:28,343 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-40-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:29,411 - INFO - Parse Artikel 40: Verhaltensregeln
# 2025-08-11 12:05:29,414 - INFO - Artikel 40: 22 Einträge extrahiert
# 2025-08-11 12:05:29,414 - INFO - Verarbeite Artikel 41/99: https://dsgvo-gesetz.de/art-41-dsgvo/
# 2025-08-11 12:05:29,415 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-41-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:30,464 - INFO - Parse Artikel 41: Überwachung der genehmigten Verhaltensregeln
# 2025-08-11 12:05:30,466 - INFO - Artikel 41: 10 Einträge extrahiert
# 2025-08-11 12:05:30,466 - INFO - Verarbeite Artikel 42/99: https://dsgvo-gesetz.de/art-42-dsgvo/
# 2025-08-11 12:05:30,467 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-42-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:31,537 - INFO - Parse Artikel 42: Zertifizierung
# 2025-08-11 12:05:31,539 - INFO - Artikel 42: 8 Einträge extrahiert
# 2025-08-11 12:05:31,539 - INFO - Verarbeite Artikel 43/99: https://dsgvo-gesetz.de/art-43-dsgvo/
# 2025-08-11 12:05:31,540 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-43-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:32,586 - INFO - Parse Artikel 43: Zertifizierungsstellen
# 2025-08-11 12:05:32,588 - INFO - Artikel 43: 16 Einträge extrahiert
# 2025-08-11 12:05:32,588 - INFO - Verarbeite Artikel 44/99: https://dsgvo-gesetz.de/art-44-dsgvo/
# 2025-08-11 12:05:32,589 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-44-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:33,644 - INFO - Parse Artikel 44: Allgemeine Grundsätze der Datenübermittlung
# 2025-08-11 12:05:33,646 - INFO - Artikel 44: 2 Einträge extrahiert
# 2025-08-11 12:05:33,646 - INFO - Verarbeite Artikel 45/99: https://dsgvo-gesetz.de/art-45-dsgvo/
# 2025-08-11 12:05:33,647 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-45-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:34,711 - INFO - Parse Artikel 45: Datenübermittlung auf der Grundlage eines Angemessenheitsbeschlusses
# 2025-08-11 12:05:34,712 - INFO - Artikel 45: 12 Einträge extrahiert
# 2025-08-11 12:05:34,713 - INFO - Verarbeite Artikel 46/99: https://dsgvo-gesetz.de/art-46-dsgvo/
# 2025-08-11 12:05:34,713 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-46-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:35,766 - INFO - Parse Artikel 46: Datenübermittlung vorbehaltlich geeigneter Garantien
# 2025-08-11 12:05:35,768 - INFO - Artikel 46: 13 Einträge extrahiert
# 2025-08-11 12:05:35,769 - INFO - Verarbeite Artikel 47/99: https://dsgvo-gesetz.de/art-47-dsgvo/
# 2025-08-11 12:05:35,769 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-47-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:36,856 - INFO - Parse Artikel 47: Verbindliche interne Datenschutzvorschriften
# 2025-08-11 12:05:36,876 - INFO - Artikel 47: 20 Einträge extrahiert
# 2025-08-11 12:05:36,877 - INFO - Verarbeite Artikel 48/99: https://dsgvo-gesetz.de/art-48-dsgvo/
# 2025-08-11 12:05:36,877 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-48-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:37,938 - INFO - Parse Artikel 48: Nach dem Unionsrecht nicht zulässige Übermittlung oder Offenlegung
# 2025-08-11 12:05:37,940 - INFO - Artikel 48: 1 Einträge extrahiert
# 2025-08-11 12:05:37,942 - INFO - Verarbeite Artikel 49/99: https://dsgvo-gesetz.de/art-49-dsgvo/
# 2025-08-11 12:05:37,942 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-49-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:38,997 - INFO - Parse Artikel 49: Ausnahmen für bestimmte Fälle
# 2025-08-11 12:05:38,999 - INFO - Artikel 49: 13 Einträge extrahiert
# 2025-08-11 12:05:38,999 - INFO - Verarbeite Artikel 50/99: https://dsgvo-gesetz.de/art-50-dsgvo/
# 2025-08-11 12:05:39,000 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-50-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:40,053 - INFO - Parse Artikel 50: Internationale Zusammenarbeit zum Schutz personenbezogener Daten
# 2025-08-11 12:05:40,054 - INFO - Artikel 50: 5 Einträge extrahiert
# 2025-08-11 12:05:40,055 - INFO - Verarbeite Artikel 51/99: https://dsgvo-gesetz.de/art-51-dsgvo/
# 2025-08-11 12:05:40,055 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-51-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:41,113 - INFO - Parse Artikel 51: Aufsichtsbehörde
# 2025-08-11 12:05:41,115 - INFO - Artikel 51: 4 Einträge extrahiert
# 2025-08-11 12:05:41,115 - INFO - Verarbeite Artikel 52/99: https://dsgvo-gesetz.de/art-52-dsgvo/
# 2025-08-11 12:05:41,115 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-52-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:42,173 - INFO - Parse Artikel 52: Unabhängigkeit
# 2025-08-11 12:05:42,174 - INFO - Artikel 52: 6 Einträge extrahiert
# 2025-08-11 12:05:42,175 - INFO - Verarbeite Artikel 53/99: https://dsgvo-gesetz.de/art-53-dsgvo/
# 2025-08-11 12:05:42,175 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-53-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:43,224 - INFO - Parse Artikel 53: Allgemeine Bedingungen für die Mitglieder der Aufsichtsbehörde
# 2025-08-11 12:05:43,230 - INFO - Artikel 53: 4 Einträge extrahiert
# 2025-08-11 12:05:43,233 - INFO - Verarbeite Artikel 54/99: https://dsgvo-gesetz.de/art-54-dsgvo/
# 2025-08-11 12:05:43,238 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-54-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:44,322 - INFO - Parse Artikel 54: Errichtung der Aufsichtsbehörde
# 2025-08-11 12:05:44,324 - INFO - Artikel 54: 8 Einträge extrahiert
# 2025-08-11 12:05:44,324 - INFO - Verarbeite Artikel 55/99: https://dsgvo-gesetz.de/art-55-dsgvo/
# 2025-08-11 12:05:44,325 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-55-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:45,408 - INFO - Parse Artikel 55: Zuständigkeit
# 2025-08-11 12:05:45,410 - INFO - Artikel 55: 3 Einträge extrahiert
# 2025-08-11 12:05:45,410 - INFO - Verarbeite Artikel 56/99: https://dsgvo-gesetz.de/art-56-dsgvo/
# 2025-08-11 12:05:45,411 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-56-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:46,472 - INFO - Parse Artikel 56: Zuständigkeit der federführenden Aufsichtsbehörde
# 2025-08-11 12:05:46,473 - INFO - Artikel 56: 6 Einträge extrahiert
# 2025-08-11 12:05:46,474 - INFO - Verarbeite Artikel 57/99: https://dsgvo-gesetz.de/art-57-dsgvo/
# 2025-08-11 12:05:46,474 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-57-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:47,539 - INFO - Parse Artikel 57: Aufgaben
# 2025-08-11 12:05:47,542 - INFO - Artikel 57: 26 Einträge extrahiert
# 2025-08-11 12:05:47,543 - INFO - Verarbeite Artikel 58/99: https://dsgvo-gesetz.de/art-58-dsgvo/
# 2025-08-11 12:05:47,543 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-58-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:48,592 - INFO - Parse Artikel 58: Befugnisse
# 2025-08-11 12:05:48,596 - INFO - Artikel 58: 32 Einträge extrahiert
# 2025-08-11 12:05:48,598 - INFO - Verarbeite Artikel 59/99: https://dsgvo-gesetz.de/art-59-dsgvo/
# 2025-08-11 12:05:48,598 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-59-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:49,655 - INFO - Parse Artikel 59: Tätigkeitsbericht
# 2025-08-11 12:05:49,657 - INFO - Artikel 59: 3 Einträge extrahiert
# 2025-08-11 12:05:49,659 - INFO - Verarbeite Artikel 60/99: https://dsgvo-gesetz.de/art-60-dsgvo/
# 2025-08-11 12:05:49,659 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-60-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:50,722 - INFO - Parse Artikel 60: Zusammenarbeit zwischen der federführenden Aufsichtsbehörde und den anderen betroffenen Aufsichtsbehörden
# 2025-08-11 12:05:50,726 - INFO - Artikel 60: 12 Einträge extrahiert
# 2025-08-11 12:05:50,726 - INFO - Verarbeite Artikel 61/99: https://dsgvo-gesetz.de/art-61-dsgvo/
# 2025-08-11 12:05:50,727 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-61-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:51,787 - INFO - Parse Artikel 61: Gegenseitige Amtshilfe
# 2025-08-11 12:05:51,789 - INFO - Artikel 61: 11 Einträge extrahiert
# 2025-08-11 12:05:51,789 - INFO - Verarbeite Artikel 62/99: https://dsgvo-gesetz.de/art-62-dsgvo/
# 2025-08-11 12:05:51,790 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-62-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:52,861 - INFO - Parse Artikel 62: Gemeinsame Maßnahmen der Aufsichtsbehörden
# 2025-08-11 12:05:52,862 - INFO - Artikel 62: 7 Einträge extrahiert
# 2025-08-11 12:05:52,863 - INFO - Verarbeite Artikel 63/99: https://dsgvo-gesetz.de/art-63-dsgvo/
# 2025-08-11 12:05:52,863 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-63-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:53,916 - INFO - Parse Artikel 63: Kohärenzverfahren
# 2025-08-11 12:05:53,918 - INFO - Artikel 63: 1 Einträge extrahiert
# 2025-08-11 12:05:53,919 - INFO - Verarbeite Artikel 64/99: https://dsgvo-gesetz.de/art-64-dsgvo/
# 2025-08-11 12:05:53,920 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-64-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:55,185 - INFO - Parse Artikel 64: Stellungnahme des Ausschusses
# 2025-08-11 12:05:55,195 - INFO - Artikel 64: 16 Einträge extrahiert
# 2025-08-11 12:05:55,199 - INFO - Verarbeite Artikel 65/99: https://dsgvo-gesetz.de/art-65-dsgvo/
# 2025-08-11 12:05:55,202 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-65-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:56,279 - INFO - Parse Artikel 65: Streitbeilegung durch den Ausschuss
# 2025-08-11 12:05:56,280 - INFO - Artikel 65: 9 Einträge extrahiert
# 2025-08-11 12:05:56,280 - INFO - Verarbeite Artikel 66/99: https://dsgvo-gesetz.de/art-66-dsgvo/
# 2025-08-11 12:05:56,281 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-66-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:57,546 - INFO - Parse Artikel 66: Dringlichkeitsverfahren
# 2025-08-11 12:05:57,547 - INFO - Artikel 66: 4 Einträge extrahiert
# 2025-08-11 12:05:57,547 - INFO - Verarbeite Artikel 67/99: https://dsgvo-gesetz.de/art-67-dsgvo/
# 2025-08-11 12:05:57,548 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-67-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:58,612 - INFO - Parse Artikel 67: Informationsaustausch
# 2025-08-11 12:05:58,613 - INFO - Artikel 67: 2 Einträge extrahiert
# 2025-08-11 12:05:58,614 - INFO - Verarbeite Artikel 68/99: https://dsgvo-gesetz.de/art-68-dsgvo/
# 2025-08-11 12:05:58,614 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-68-dsgvo/ (Versuch 1)
# 2025-08-11 12:05:59,676 - INFO - Parse Artikel 68: Europäischer Datenschutzausschuss
# 2025-08-11 12:05:59,678 - INFO - Artikel 68: 6 Einträge extrahiert
# 2025-08-11 12:05:59,678 - INFO - Verarbeite Artikel 69/99: https://dsgvo-gesetz.de/art-69-dsgvo/
# 2025-08-11 12:05:59,678 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-69-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:00,750 - INFO - Parse Artikel 69: Unabhängigkeit
# 2025-08-11 12:06:00,753 - INFO - Artikel 69: 2 Einträge extrahiert
# 2025-08-11 12:06:00,753 - INFO - Verarbeite Artikel 70/99: https://dsgvo-gesetz.de/art-70-dsgvo/
# 2025-08-11 12:06:00,754 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-70-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:01,836 - INFO - Parse Artikel 70: Aufgaben des Ausschusses
# 2025-08-11 12:06:01,840 - INFO - Artikel 70: 29 Einträge extrahiert
# 2025-08-11 12:06:01,840 - INFO - Verarbeite Artikel 71/99: https://dsgvo-gesetz.de/art-71-dsgvo/
# 2025-08-11 12:06:01,841 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-71-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:02,917 - INFO - Parse Artikel 71: Berichterstattung
# 2025-08-11 12:06:02,919 - INFO - Artikel 71: 2 Einträge extrahiert
# 2025-08-11 12:06:02,919 - INFO - Verarbeite Artikel 72/99: https://dsgvo-gesetz.de/art-72-dsgvo/
# 2025-08-11 12:06:02,919 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-72-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:03,969 - INFO - Parse Artikel 72: Verfahrensweise
# 2025-08-11 12:06:03,970 - INFO - Artikel 72: 2 Einträge extrahiert
# 2025-08-11 12:06:03,971 - INFO - Verarbeite Artikel 73/99: https://dsgvo-gesetz.de/art-73-dsgvo/
# 2025-08-11 12:06:03,971 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-73-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:05,051 - INFO - Parse Artikel 73: Vorsitz
# 2025-08-11 12:06:05,053 - INFO - Artikel 73: 2 Einträge extrahiert
# 2025-08-11 12:06:05,053 - INFO - Verarbeite Artikel 74/99: https://dsgvo-gesetz.de/art-74-dsgvo/
# 2025-08-11 12:06:05,054 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-74-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:06,115 - INFO - Parse Artikel 74: Aufgaben des Vorsitzes
# 2025-08-11 12:06:06,119 - INFO - Artikel 74: 5 Einträge extrahiert
# 2025-08-11 12:06:06,120 - INFO - Verarbeite Artikel 75/99: https://dsgvo-gesetz.de/art-75-dsgvo/
# 2025-08-11 12:06:06,122 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-75-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:07,181 - INFO - Parse Artikel 75: Sekretariat
# 2025-08-11 12:06:07,183 - INFO - Artikel 75: 13 Einträge extrahiert
# 2025-08-11 12:06:07,183 - INFO - Verarbeite Artikel 76/99: https://dsgvo-gesetz.de/art-76-dsgvo/
# 2025-08-11 12:06:07,184 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-76-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:08,244 - INFO - Parse Artikel 76: Vertraulichkeit
# 2025-08-11 12:06:08,245 - INFO - Artikel 76: 2 Einträge extrahiert
# 2025-08-11 12:06:08,246 - INFO - Verarbeite Artikel 77/99: https://dsgvo-gesetz.de/art-77-dsgvo/
# 2025-08-11 12:06:08,246 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-77-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:09,313 - INFO - Parse Artikel 77: Recht auf Beschwerde bei einer Aufsichtsbehörde
# 2025-08-11 12:06:09,314 - INFO - Artikel 77: 2 Einträge extrahiert
# 2025-08-11 12:06:09,315 - INFO - Verarbeite Artikel 78/99: https://dsgvo-gesetz.de/art-78-dsgvo/
# 2025-08-11 12:06:09,315 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-78-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:10,378 - INFO - Parse Artikel 78: Recht auf wirksamen gerichtlichen Rechtsbehelf gegen eine Aufsichtsbehörde
# 2025-08-11 12:06:10,380 - INFO - Artikel 78: 4 Einträge extrahiert
# 2025-08-11 12:06:10,380 - INFO - Verarbeite Artikel 79/99: https://dsgvo-gesetz.de/art-79-dsgvo/
# 2025-08-11 12:06:10,381 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-79-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:11,444 - INFO - Parse Artikel 79: Recht auf wirksamen gerichtlichen Rechtsbehelf gegen Verantwortliche oder Auftragsverarbeiter
# 2025-08-11 12:06:11,445 - INFO - Artikel 79: 2 Einträge extrahiert
# 2025-08-11 12:06:11,446 - INFO - Verarbeite Artikel 80/99: https://dsgvo-gesetz.de/art-80-dsgvo/
# 2025-08-11 12:06:11,447 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-80-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:12,514 - INFO - Parse Artikel 80: Vertretung von betroffenen Personen
# 2025-08-11 12:06:12,516 - INFO - Artikel 80: 2 Einträge extrahiert
# 2025-08-11 12:06:12,516 - INFO - Verarbeite Artikel 81/99: https://dsgvo-gesetz.de/art-81-dsgvo/
# 2025-08-11 12:06:12,517 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-81-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:13,572 - INFO - Parse Artikel 81: Aussetzung des Verfahrens
# 2025-08-11 12:06:13,574 - INFO - Artikel 81: 3 Einträge extrahiert
# 2025-08-11 12:06:13,575 - INFO - Verarbeite Artikel 82/99: https://dsgvo-gesetz.de/art-82-dsgvo/
# 2025-08-11 12:06:13,575 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-82-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:14,622 - INFO - Parse Artikel 82: Haftung und Recht auf Schadenersatz
# 2025-08-11 12:06:14,623 - INFO - Artikel 82: 6 Einträge extrahiert
# 2025-08-11 12:06:14,624 - INFO - Verarbeite Artikel 83/99: https://dsgvo-gesetz.de/art-83-dsgvo/
# 2025-08-11 12:06:14,624 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-83-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:15,676 - INFO - Parse Artikel 83: Allgemeine Bedingungen für die Verhängung von Geldbußen
# 2025-08-11 12:06:15,680 - INFO - Artikel 83: 28 Einträge extrahiert
# 2025-08-11 12:06:15,680 - INFO - Verarbeite Artikel 84/99: https://dsgvo-gesetz.de/art-84-dsgvo/
# 2025-08-11 12:06:15,681 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-84-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:16,730 - INFO - Parse Artikel 84: Sanktionen
# 2025-08-11 12:06:16,732 - INFO - Artikel 84: 2 Einträge extrahiert
# 2025-08-11 12:06:16,732 - INFO - Verarbeite Artikel 85/99: https://dsgvo-gesetz.de/art-85-dsgvo/
# 2025-08-11 12:06:16,732 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-85-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:17,779 - INFO - Parse Artikel 85: Verarbeitung und Freiheit der Meinungsäußerung und Informationsfreiheit
# 2025-08-11 12:06:17,781 - INFO - Artikel 85: 3 Einträge extrahiert
# 2025-08-11 12:06:17,782 - INFO - Verarbeite Artikel 86/99: https://dsgvo-gesetz.de/art-86-dsgvo/
# 2025-08-11 12:06:17,782 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-86-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:18,842 - INFO - Parse Artikel 86: Verarbeitung und Zugang der Öffentlichkeit zu amtlichen Dokumenten
# 2025-08-11 12:06:18,844 - INFO - Artikel 86: 1 Einträge extrahiert
# 2025-08-11 12:06:18,846 - INFO - Verarbeite Artikel 87/99: https://dsgvo-gesetz.de/art-87-dsgvo/
# 2025-08-11 12:06:18,846 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-87-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:19,923 - INFO - Parse Artikel 87: Verarbeitung der nationalen Kennziffer
# 2025-08-11 12:06:19,925 - INFO - Artikel 87: 2 Einträge extrahiert
# 2025-08-11 12:06:19,926 - INFO - Verarbeite Artikel 88/99: https://dsgvo-gesetz.de/art-88-dsgvo/
# 2025-08-11 12:06:19,927 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-88-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:20,987 - INFO - Parse Artikel 88: Datenverarbeitung im Beschäftigungskontext
# 2025-08-11 12:06:20,988 - INFO - Artikel 88: 3 Einträge extrahiert
# 2025-08-11 12:06:20,989 - INFO - Verarbeite Artikel 89/99: https://dsgvo-gesetz.de/art-89-dsgvo/
# 2025-08-11 12:06:20,990 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-89-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:22,046 - INFO - Parse Artikel 89: Garantien und Ausnahmen in Bezug auf die Verarbeitung zu im öffentlichen Interesse liegenden Archivzwecken, zu wissenschaftlichen oder historischen Forschungszwecken und zu statistischen Zwecken
# 2025-08-11 12:06:22,050 - INFO - Artikel 89: 4 Einträge extrahiert
# 2025-08-11 12:06:22,052 - INFO - Verarbeite Artikel 90/99: https://dsgvo-gesetz.de/art-90-dsgvo/
# 2025-08-11 12:06:22,054 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-90-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:23,131 - INFO - Parse Artikel 90: Geheimhaltungspflichten
# 2025-08-11 12:06:23,133 - INFO - Artikel 90: 2 Einträge extrahiert
# 2025-08-11 12:06:23,134 - INFO - Verarbeite Artikel 91/99: https://dsgvo-gesetz.de/art-91-dsgvo/
# 2025-08-11 12:06:23,134 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-91-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:24,423 - INFO - Parse Artikel 91: Bestehende Datenschutzvorschriften von Kirchen und religiösen Vereinigungen oder Gemeinschaften
# 2025-08-11 12:06:24,428 - INFO - Artikel 91: 2 Einträge extrahiert
# 2025-08-11 12:06:24,432 - INFO - Verarbeite Artikel 92/99: https://dsgvo-gesetz.de/art-92-dsgvo/
# 2025-08-11 12:06:24,434 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-92-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:25,723 - INFO - Parse Artikel 92: Ausübung der Befugnisübertragung
# 2025-08-11 12:06:25,726 - INFO - Artikel 92: 5 Einträge extrahiert
# 2025-08-11 12:06:25,728 - INFO - Verarbeite Artikel 93/99: https://dsgvo-gesetz.de/art-93-dsgvo/
# 2025-08-11 12:06:25,729 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-93-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:26,784 - INFO - Parse Artikel 93: Ausschussverfahren
# 2025-08-11 12:06:26,785 - INFO - Artikel 93: 3 Einträge extrahiert
# 2025-08-11 12:06:26,786 - INFO - Verarbeite Artikel 94/99: https://dsgvo-gesetz.de/art-94-dsgvo/
# 2025-08-11 12:06:26,786 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-94-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:28,067 - INFO - Parse Artikel 94: Aufhebung der Richtlinie 95/46/EG
# 2025-08-11 12:06:28,072 - INFO - Artikel 94: 2 Einträge extrahiert
# 2025-08-11 12:06:28,072 - INFO - Verarbeite Artikel 95/99: https://dsgvo-gesetz.de/art-95-dsgvo/
# 2025-08-11 12:06:28,073 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-95-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:29,146 - INFO - Parse Artikel 95: Verhältnis zur Richtlinie 2002/58/EG
# 2025-08-11 12:06:29,148 - INFO - Artikel 95: 1 Einträge extrahiert
# 2025-08-11 12:06:29,148 - INFO - Verarbeite Artikel 96/99: https://dsgvo-gesetz.de/art-96-dsgvo/
# 2025-08-11 12:06:29,148 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-96-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:30,232 - INFO - Parse Artikel 96: Verhältnis zu bereits geschlossenen Übereinkünften
# 2025-08-11 12:06:30,234 - INFO - Artikel 96: 1 Einträge extrahiert
# 2025-08-11 12:06:30,234 - INFO - Verarbeite Artikel 97/99: https://dsgvo-gesetz.de/art-97-dsgvo/
# 2025-08-11 12:06:30,235 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-97-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:31,294 - INFO - Parse Artikel 97: Berichte der Kommission
# 2025-08-11 12:06:31,296 - INFO - Artikel 97: 7 Einträge extrahiert
# 2025-08-11 12:06:31,296 - INFO - Verarbeite Artikel 98/99: https://dsgvo-gesetz.de/art-98-dsgvo/
# 2025-08-11 12:06:31,297 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-98-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:32,557 - INFO - Parse Artikel 98: Überprüfung anderer Rechtsakte der Union zum Datenschutz
# 2025-08-11 12:06:32,559 - INFO - Artikel 98: 2 Einträge extrahiert
# 2025-08-11 12:06:32,559 - INFO - Verarbeite Artikel 99/99: https://dsgvo-gesetz.de/art-99-dsgvo/
# 2025-08-11 12:06:32,560 - INFO - Lade Seite: https://dsgvo-gesetz.de/art-99-dsgvo/ (Versuch 1)
# 2025-08-11 12:06:33,613 - INFO - Parse Artikel 99: Inkrafttreten und Anwendung
# 2025-08-11 12:06:33,616 - INFO - Artikel 99: 2 Einträge extrahiert
# 2025-08-11 12:06:33,616 - INFO - Crawling abgeschlossen. Insgesamt 780 Einträge extrahiert.
# 2025-08-11 12:06:33,617 - INFO - Speichere 780 Einträge in: ../data/output/dsgvo_crawled_2025-08-11_1204.jsonl
# 2025-08-11 12:06:33,626 - INFO - Erfolgreich gespeichert: ../data/output/dsgvo_crawled_2025-08-11_1204.jsonl
# 2025-08-11 12:06:33,627 - INFO - === CRAWLING STATISTIKEN ===
# 2025-08-11 12:06:33,627 - INFO - Gesamt Einträge: 780
# 2025-08-11 12:06:33,628 - INFO - Artikel verarbeitet: 99
# 2025-08-11 12:06:33,629 - INFO - Kapitel verarbeitet: 11
# \n✅ Crawling erfolgreich abgeschlossen!
# 📄 Ausgabedatei: ../data/output/dsgvo_crawled_2025-08-11_1204.jsonl
# 📁 Log-Datei: ../data/logs/crawler.log
# \n📋 Erste 3 Einträge:
# 1. Artikel 1, Absatz 1, Satz 1
#    Text: Diese Verordnung enthält Vorschriften zum Schutz natürlicher Personen bei der Verarbeitung personenb...
# 2. Artikel 1, Absatz 2, Satz 1
#    Text: Diese Verordnung schützt die Grundrechte und Grundfreiheiten natürlicher Personen und insbesondere d...
# 3. Artikel 1, Absatz 3, Satz 1
#    Text: Der freie Verkehr personenbezogener Daten in der Union darf aus Gründen des Schutzes natürlicher Per...
